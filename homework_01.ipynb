# %%
print("Меня зовут Сафиуллин Артём, и я готов страдать на курсе!")
# Out:
# Меня зовут Сафиуллин Артём, и я готов страдать на курсе!

# %%
77%2
# Out:
# 1

# %%
print("Четное" if 22%2 == 0 else "Нечетное")
# Out:
# Четное

# %%
86**7
# Out:
# 34792782221696

# %%
3686400**0.5
# Out:
# 1920.0
